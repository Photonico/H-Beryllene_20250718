# %% [markdown]
# # Phonon dispersion
#
# for β-Beryllene trilayer with Hydrogen Adhesion
#
# note:
#     * full hh3 = full hh2 ≈ full hh1
#     * full top ≈ full h1
#     * third th2 = third hh4
#     * third tt = third hh1

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt
y_range = [-30, 30]

# %%
# β-Beryllene trilayer with full freqence top Hydrogen Adhesion

# matters = [["full top", "3.0_phonon_dispersion_with_hydrogen_b/b-Beryllene_full_t", "blue", "solid", 1.5, 1.0, 0]]

# plot_phonons("Phonon dispersion (full top)", matters, y_range, None)

# %%
# β-Beryllene trilayer with full freqence hollow Hydrogen Adhesion

matters = [["full hollow", "3.0_phonon_dispersion_with_hydrogen_b/b-Beryllene_full_h1", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow 1)", matters, y_range, None)

# %%
# β-Beryllene trilayer with full freqence hollow Hydrogen Adhesion

matters = [["full hollow", "3.0_phonon_dispersion_with_hydrogen_b/b-Beryllene_full_h2", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow 2)", matters, y_range, None)

# %%
# β-Beryllene trilayer with full freqence top-top Hydrogen Adhesion

# matters = [["full top-top", "3.0_phonon_dispersion_with_hydrogen_b/b-Beryllene_full_tt", "blue", "solid", 1.5, 1.0, 0]]

# plot_phonons("Phonon dispersion (full top-top)", matters, y_range, None)

# %%
# β-Beryllene trilayer with full freqence hollow-hollow Hydrogen Adhesion

matters = [["full hollow-hollow", "3.0_phonon_dispersion_with_hydrogen_b/b-Beryllene_full_hh1", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow-hollow 1)", matters, y_range, None)

# %%
# β-Beryllene trilayer with full freqence hollow-hollow Hydrogen Adhesion

matters = [["full hollow-hollow", "3.0_phonon_dispersion_with_hydrogen_b/b-Beryllene_full_hh2", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow-hollow 2)", matters, y_range, None)

# %%
# β-Beryllene trilayer with full freqence hollow-hollow Hydrogen Adhesion

matters = [["full hollow-hollow", "3.0_phonon_dispersion_with_hydrogen_b/b-Beryllene_full_hh3", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow-hollow 3)", matters, y_range, None)

# %%
# β-Beryllene trilayer with full freqence top-hollow Hydrogen Adhesion

# matters = [["full top-hollow", "3.0_phonon_dispersion_with_hydrogen_b/b-Beryllene_full_th1", "blue", "solid", 1.5, 1.0, 0]]

# plot_phonons("Phonon dispersion (full top-hollow 1)", matters, y_range, None)

# %%
# β-Beryllene trilayer with full freqence top-hollow Hydrogen Adhesion

# matters = [["full top-hollow", "3.0_phonon_dispersion_with_hydrogen_b/b-Beryllene_full_th2", "blue", "solid", 1.5, 1.0, 0]]

# plot_phonons("Phonon dispersion (full top-hollow 2)", matters, y_range, None)

# %% [markdown]
# # Projected Density of State

# %%
# prework

from vmatplot.commons import get_elements, get_elements_coordinates

# %%
directory = "5.0_PDoS/a-Beryllium"
elements = get_elements(directory)
print("α Beryllium bulk:", elements)

directory = "5.0_PDoS/a-Beryllene"
elements = get_elements(directory)
print("α Beryllene:", elements)

directory = "5.0_PDoS/b-Beryllene"
elements = get_elements(directory)
print("β Beryllene:", elements)

directory = "5.0_PDoS/c0-Beryllium"
elements = get_elements(directory)
print("cubc Beryllium bulk:", elements)

directory = "5.0_PDoS/c3-Beryllene"
elements = get_elements(directory)
print("cubic Beryllene trilayer:", elements)

"""
α Beryllium bulk: {'Be': (1, 2)}
α Beryllene: {'Be': (1, 1)}
β Beryllene: {'Be': (1, 2)}
cubc Beryllium bulk: {'Be': (1, 1)}
cubic Beryllene trilayer: {'Be': (1, 3)}
"""
# Out:
# α Beryllium bulk: {'Be': (1, 2)}
# α Beryllene: {'Be': (1, 1)}
# β Beryllene: {'Be': (1, 2)}
# cubc Beryllium bulk: {'Be': (1, 1)}
# cubic Beryllene trilayer: {'Be': (1, 3)}
# "\nα Beryllium bulk: {'Be': (1, 2)}\nα Beryllene: {'Be': (1, 1)}\nβ Beryllene: {'Be': (1, 2)}\ncubc Beryllium bulk: {'Be': (1, 1)}\ncubic Beryllene trilayer: {'Be': (1, 3)}\n"

# %%
# α Beryllium bulk

directory = "5.0_PDoS/a-Beryllium"
coordinates = get_elements_coordinates(directory)
print(coordinates)

"""
[{'index': 1, 'element': 'Be', 'coordinates': (0.33333333, 0.66666667, 0.75)},
{'index': 2, 'element': 'Be', 'coordinates': (0.66666667, 0.33333333, 0.25)}]
"""
# Out:
# [{'index': 1, 'element': 'Be', 'coordinates': (0.33333333, 0.66666667, 0.75)}, {'index': 2, 'element': 'Be', 'coordinates': (0.66666667, 0.33333333, 0.25)}]
# "\n[{'index': 1, 'element': 'Be', 'coordinates': (0.0, 0.0, 0.13758112)},\n{'index': 2, 'element': 'Be', 'coordinates': (0.5, 0.5, 0.1)},\n{'index': 3, 'element': 'Be', 'coordinates': (0.0, 0.0, 0.06241888)}]\n"

# %%
# β Beryllene

directory = "5.0_PDoS/b-Beryllene"
coordinates = get_elements_coordinates(directory)
print(coordinates)

"""
[{'index': 1, 'element': 'Be', 'coordinates': (0.34679415, 0.68248722, 0.12368858)},
{'index': 2, 'element': 'Be', 'coordinates': (0.65320585, 0.31751278, 0.07631142)}]
"""
# Out:
# [{'index': 1, 'element': 'Be', 'coordinates': (0.34679415, 0.68248722, 0.12368858)}, {'index': 2, 'element': 'Be', 'coordinates': (0.65320585, 0.31751278, 0.07631142)}]
# "\n[{'index': 1, 'element': 'Be', 'coordinates': (0.0, 0.0, 0.0)}]\n"

# %%
# cubic Beryllene trilayer

directory = "5.0_PDoS/c3-Beryllene"
coordinates = get_elements_coordinates(directory)
print(coordinates)

"""
[{'index': 1, 'element': 'Be', 'coordinates': (0.0, 0.0, 0.13758112)},
{'index': 2, 'element': 'Be', 'coordinates': (0.5, 0.5, 0.1)},
{'index': 3, 'element': 'Be', 'coordinates': (0.0, 0.0, 0.06241888)}]
"""
# Out:
# [{'index': 1, 'element': 'Be', 'coordinates': (0.0, 0.0, 0.13758112)}, {'index': 2, 'element': 'Be', 'coordinates': (0.5, 0.5, 0.1)}, {'index': 3, 'element': 'Be', 'coordinates': (0.0, 0.0, 0.06241888)}]
# "\n[{'index': 1, 'element': 'Be', 'coordinates': (0.0, 0.0, 0.13758112)},\n{'index': 2, 'element': 'Be', 'coordinates': (0.5, 0.5, 0.1)},\n{'index': 3, 'element': 'Be', 'coordinates': (0.0, 0.0, 0.06241888)}]\n"

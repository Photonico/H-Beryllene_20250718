# %% [markdown]
# # Band structure

# %%
# prework

from vmatplot.bandstructure import plot_bandstructure
import matplotlib.pyplot as plt

# %%
# α-Beryllium bulk

bs_list = [["monocolor", "α-Beryllium", "4.0_bandstructure/a0-Beryllium", "purple"]]

plot_bandstructure("Bandstructure for α-Beryllium bulk", bs_list, (-6,6), True)
plt.savefig("figures/3.41_bs_a-Beryllium.pdf")

# %%
# α-Beryllene monolayer

bs_list = [["monocolor", "α-Beryllene monolayer", "4.0_bandstructure/a1-Beryllene_monolayer_initial", "violet"]]

plot_bandstructure("Bandstructure for α-Beryllene monolayer", bs_list, (-6,6), True)
plt.savefig("figures/3.42_bs_a-Beryllene.pdf")

# %%
# g-Beryllene monolayer: blue

bs_list = [["monocolor", "g-Beryllene monolayer", "4.0_bandstructure/g-Beryllene_monolayer", "blue"]]

plot_bandstructure("Bandstructure for g-Beryllene monolayer", bs_list, (-6,6), True)
plt.savefig("figures/3.43_bs_g-Beryllene.pdf")

# %%
# c-Beryllene bulk

bs_list = [["monocolor", "c-Beryllene bulk", "4.0_bandstructure/c0-Beryllene_bulk", "cyan"]]

plot_bandstructure("Bandstructure for cubic Beryllene bluk", bs_list, (-8,8), True)
plt.savefig("figures/3.44_bs_c_bulk.pdf")

# %%
# c-Beryllene monolayer

bs_list = [["monocolor", "c-Beryllene monolayer", "4.0_bandstructure/c1-Beryllene_monolayer", "lime"]]

plot_bandstructure("Bandstructure for cubic Beryllene monolayer", bs_list, (-8,8), True)
plt.savefig("figures/3.45_bs_c_monolayer.pdf")

# %%
# c-Beryllene bilayer

bs_list = [["monocolor", "c-Beryllene bilayer", "4.0_bandstructure/c2-Beryllene_bilayer", "yellow"]]

plot_bandstructure("Bandstructure for cubic Beryllene bilayer", bs_list, (-8,8), True)
plt.savefig("figures/3.46_bs_c_bilayer.pdf")

# %%
# c-Beryllene trilayer

bs_list = [["monocolor", "c-Beryllene trilayer", "4.0_bandstructure/c3-Beryllene_trilayer", "orange"]]

plot_bandstructure("Bandstructure for cubic Beryllene trilayer", bs_list, (-8,8), True)
plt.savefig("figures/3.47_bs_c_trilayer.pdf")

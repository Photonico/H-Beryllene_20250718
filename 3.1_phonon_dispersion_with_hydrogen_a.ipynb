# %% [markdown]
# # Phonon dispersion
#
# for α-Beryllene with Hydrogen Adhesion
#
# note:
#     * full hh1 = full bb
#     * third hh1 = third bb
#     * third th = third hh3

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt
y_range = [-20, 30]

# %%
# α-Beryllene with full freqence top Hydrogen Adhesion

matters = [["full top", "3.1_phonon_dispersion_with_hydrogen_a/a-Beryllene_t", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full top)", matters, y_range, None)
# Out:
# {'full top': {'x': 1.0880260229654863,
#   'freq_THz': -28.078349,
#   'backend': 'vasp',
#   'directory': '3.1_phonon_dispersion_with_hydrogen_a/a-Beryllene_t'}}

# %%
# α-Beryllene with full freqence hollow Hydrogen Adhesion

matters = [["full hollow", "3.1_phonon_dispersion_with_hydrogen_a/a-Beryllene_h", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow)", matters, y_range, None)
# Out:
# {'full hollow': {'x': 0.0,
#   'freq_THz': -18.085979,
#   'backend': 'vasp',
#   'directory': '3.1_phonon_dispersion_with_hydrogen_a/a-Beryllene_h'}}

# %%
# α-Beryllene with full freqence top-top Hydrogen Adhesion

matters = [["full top-top", "3.1_phonon_dispersion_with_hydrogen_a/a-Beryllene_tt", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full top-top)", matters, y_range, None)
# Out:
# {'full top-top': {'x': 0.0,
#   'freq_THz': -17.154073,
#   'backend': 'vasp',
#   'directory': '3.1_phonon_dispersion_with_hydrogen_a/a-Beryllene_tt'}}

# %%
# α-Beryllene with full freqence hollow-hollow Hydrogen Adhesion

matters = [["full top-top", "3.1_phonon_dispersion_with_hydrogen_a/a-Beryllene_hh1", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow-hollow 1)", matters, y_range, None)
# Out:
# {'full top-top': {'x': 0.3327283068633982,
#   'freq_THz': -27.986935,
#   'backend': 'vasp',
#   'directory': '3.1_phonon_dispersion_with_hydrogen_a/a-Beryllene_hh1'}}

# %%
# α-Beryllene with full freqence hollow-hollow Hydrogen Adhesion

matters = [["full top-top", "3.1_phonon_dispersion_with_hydrogen_a/a-Beryllene_hh2", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow-hollow 2)", matters, y_range, None)
# Out:
# {'full top-top': {'x': 0.0,
#   'freq_THz': -0.024645,
#   'backend': 'vasp',
#   'directory': '3.1_phonon_dispersion_with_hydrogen_a/a-Beryllene_hh2'}}

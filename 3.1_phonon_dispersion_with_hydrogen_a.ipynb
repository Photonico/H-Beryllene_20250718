# %% [markdown]
# # Phonon dispersion
#
# for α-beryllene with Hydrogen Adhesion
#
# note:
#     * full hh1 = full bb
#     * third hh1 = third bb
#     * third th = third hh3

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt
y_range = [-20, 30]

# %%
# α-beryllene with full freqence top Hydrogen Adhesion

matters = [["top", "3.1_phonon_dispersion_with_hydrogen_a/a-beryllene_t", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("α-beryllene (top)", matters, y_range, None)
# Out:
# {'top': {'x': 1.1122162934707123,
#   'freq_THz': -28.078349,
#   'backend': 'vasp',
#   'directory': '3.1_phonon_dispersion_with_hydrogen_a/a-beryllene_t'}}

# %%
# α-beryllene with full freqence hollow Hydrogen Adhesion

matters = [["hollow", "3.1_phonon_dispersion_with_hydrogen_a/a-beryllene_h", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("α-beryllene (hollow)", matters, y_range, None)
# Out:
# {'hollow': {'x': 0.0,
#   'freq_THz': -18.085979,
#   'backend': 'vasp',
#   'directory': '3.1_phonon_dispersion_with_hydrogen_a/a-beryllene_h'}}

# %%
# α-beryllene with full freqence top-top Hydrogen Adhesion

matters = [["top-top", "3.1_phonon_dispersion_with_hydrogen_a/a-beryllene_tt", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("α-beryllene (top-top)", matters, y_range, None)
# Out:
# {'top-top': {'x': 0.0,
#   'freq_THz': -17.154073,
#   'backend': 'vasp',
#   'directory': '3.1_phonon_dispersion_with_hydrogen_a/a-beryllene_tt'}}

# %%
# α-beryllene with full freqence hollow-hollow Hydrogen Adhesion

matters = [["top-top", "3.1_phonon_dispersion_with_hydrogen_a/a-beryllene_hh1", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("α-beryllene (hollow-hollow 1)", matters, y_range, None)
# Out:
# {'top-top': {'x': 0.43623397670064035,
#   'freq_THz': -27.986935,
#   'backend': 'vasp',
#   'directory': '3.1_phonon_dispersion_with_hydrogen_a/a-beryllene_hh1'}}

# %%
# α-beryllene with full freqence hollow-hollow Hydrogen Adhesion

matters = [["top-top", "3.1_phonon_dispersion_with_hydrogen_a/a-beryllene_hh2", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("α-beryllene (hollow-hollow 2)", matters, y_range, None)
# Out:
# {'top-top': {'x': 0.0,
#   'freq_THz': -0.024645,
#   'backend': 'vasp',
#   'directory': '3.1_phonon_dispersion_with_hydrogen_a/a-beryllene_hh2'}}

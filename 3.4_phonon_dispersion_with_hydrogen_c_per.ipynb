# %% [markdown]
# # Phonon dispersion
#
# for cubic-Beryllene trilayer with Hydrogen Adhesion with perturbation sitted
#
# note:
#
# cubic-Beryllene full top-hollow: become a hex family system

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt
y_range = [-30, 20]

# %%
# cubic-Beryllene trilayer with full freqence top Hydrogen Adhesion

matters = [["full top", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_t", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full top)", matters, y_range, None)
# Out:
# {'full top': {'x': 0.9233800105734754,
#   'freq_THz': -18.854675,
#   'backend': 'vasp',
#   'directory': '3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_t'}}

# %%
# cubic-Beryllene trilayer with full freqence hollow Hydrogen Adhesion

matters = [["full hollow", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_h", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow)", matters, y_range, None)
# Out:
# {'full hollow': {'x': 0.0,
#   'freq_THz': -41.69493,
#   'backend': 'vasp',
#   'directory': '3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_h'}}

# %%
# cubic-Beryllene trilayer with full freqence top-top Hydrogen Adhesion

matters = [["full top-top", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_tt", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full top-top)", matters, y_range, None)
# Out:
# {'full top-top': {'x': 1.1230797769053742,
#   'freq_THz': -19.169802,
#   'backend': 'vasp',
#   'directory': '3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_tt'}}

# %%
# cubic-Beryllene trilayer with full freqence hollow-hollow Hydrogen Adhesion

matters = [["full hollow-hollow", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_hh", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow-hollow)", matters, y_range, None)
# Out:
# {'full hollow-hollow': {'x': 1.1497855930067788,
#   'freq_THz': -45.428053,
#   'backend': 'vasp',
#   'directory': '3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_hh'}}

# %%
# # cubic-Beryllene trilayer with full freqence top-hollow Hydrogen Adhesion

matters = [["full top", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_th", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full top-hollow)", matters, y_range, None)
# Out:
# {'full top': {'x': 0.0,
#   'freq_THz': -35.661922,
#   'backend': 'vasp',
#   'directory': '3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_th'}}

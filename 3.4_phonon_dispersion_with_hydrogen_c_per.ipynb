# %% [markdown]
# # Phonon dispersion
#
# for cubic-Beryllene trilayer with Hydrogen Adhesion with perturbation sitted
#
# note:
#
# cubic-Beryllene full top-hollow: become a hex family system

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt
y_range = [-20, 50]

# %%
# cubic-Beryllene trilayer with full freqence top Hydrogen Adhesion

matters = [["top", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_t", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("cubic-Beryllene trilayer (top)", matters, y_range, None)
# Out:
# {'top': {'x': 0.9233797836903894,
#   'freq_THz': -18.854675,
#   'backend': 'vasp',
#   'directory': '3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_t'}}

# %%
# cubic-Beryllene trilayer with full freqence hollow Hydrogen Adhesion

matters = [["hollow", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_h", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("cubic-Beryllene trilayer (hollow)", matters, y_range, None)
# Out:
# {'hollow': {'x': 0.0,
#   'freq_THz': -41.69493,
#   'backend': 'vasp',
#   'directory': '3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_h'}}

# %%
# cubic-Beryllene trilayer with full freqence top-top Hydrogen Adhesion

matters = [["top-top", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_tt", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("cubic-Beryllene trilayer (top-top)", matters, y_range, None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       1 # cubic-Beryllene trilayer with full freqence top-top Hydrogen Adhesion
#       3 matters = [["top-top", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_tt", "blue", "solid", 1.5, 1.0, 0]]
# ----> 5 plot_phonons("cubic-Beryllene trilayer (top-top)", matters, y_range, None)
#
# File c:\Users\lniu6305\Repos\G-Beryllene_20250718\vmatplot\phonon.py:632, in plot_phonons(title, matters_list, eigen_range, legend_loc)
#     629 annotate_color = color_sampling("Grey")
#     631 # Create matters using the updated create_matters_phonons
# --> 632 matters = create_matters_phonons(matters_list)
#     634 # If VASP- and Phonopy-based dispersions are plotted together, their k-path distances can
#     635 # differ by a constant scale (e.g. 2π convention). To make overlays comparable, rescale
#     636 # the Phonopy k-path to the VASP k-path range.
#     637 has_vasp = any(m[-1] == "vasp" for m in matters)
#
# File c:\Users\lniu6305\Repos\G-Beryllene_20250718\vmatplot\phonon.py:595, in create_matters_phonons(matters_list)
#     593         bands = bands_data["bands"]
#     594     else:
# --> 595         raise FileNotFoundError(
#     596             f"Cannot detect a phonon backend under '{directory}'. "
#     597             "Expected either (OUTCAR + QPOINTS/QPOINTS_OPT) for direct VASP, "
#     598             "or band.yaml / phonopy_disp.yaml for phonopy."
#     599         )
#     600     matters.append([label, 0, qpath, bands, color, lstyle, weight, alpha, tolerance, backend])
#     601 return matters
#
# FileNotFoundError: Cannot detect a phonon backend under '3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_tt'. Expected either (OUTCAR + QPOINTS/QPOINTS_OPT) for direct VASP, or band.yaml / phonopy_disp.yaml for phonopy.

# %%
# cubic-Beryllene trilayer with full freqence hollow-hollow Hydrogen Adhesion

matters = [["hollow-hollow", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_hh", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("cubic-Beryllene trilayer (hollow-hollow)", matters, y_range, None)

# %%
# # cubic-Beryllene trilayer with full freqence top-hollow Hydrogen Adhesion

matters = [["top", "3.4_phonon_dispersion_with_hydrogen_c_shift/c-Beryllene_th", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("cubic-Beryllene trilayer (top-hollow)", matters, y_range, None)

# %% [markdown]
# # Phonon dispersion

# %%
# prework

from vmatplot.phonon_alt import plot_phonons
import matplotlib.pyplot as plt

y_range = [0, 30]

# %%
# cubic-Beryllium

matters = [["c-Beryllium", "3.0_phonon_dispersion/c0-Beryllium_3_alt", "blue", "solid", 1.5, 1.0, 0]]
plot_phonons("Phonon dispersion for bulk bcc beryllium", matters, y_range, None)

plt.savefig("figures/3_phonon/3.20_phonon_c-Beryllium_alt.pdf")
plt.savefig("figures_for_publication/S3.13c_phonon_bcc_alt.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # cubic-Beryllium
#       3 matters = [["c-Beryllium", "3.0_phonon_dispersion/c0-Beryllium_3_alt", "blue", "solid", 1.5, 1.0, 0]]
# ----> 4 plot_phonons("Phonon dispersion for bulk bcc beryllium", matters, y_range, None)
#       6 plt.savefig("figures/3_phonon/3.20_phonon_c-Beryllium_alt.pdf")
#       7 plt.savefig("figures_for_publication/S3.13c_phonon_bcc_alt.pdf")
#
# NameError: name 'plot_phonons' is not defined

# %% [markdown]
# # Phonon dispersion
#
# with Hydrogen

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt
y_range = [-10, 60]

# %%
# a-beryllene_hh

matters = [["α-beryllene", "3.5_phonon_dispersion_with_hydrogen_selected/a-beryllene_hh", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("α-beryllene with Hydrogen (double side adhesion)", matters, y_range, None)
# plt.savefig("figures/3_phonon/3.31_phonon_a_hh_phonopy.pdf")
# Out:
# {'α-beryllene': {'x': 0.0,
#   'freq_THz': -0.0201107165,
#   'backend': 'phonopy',
#   'directory': '3.5_phonon_dispersion_with_hydrogen_selected/a-beryllene_hh'}}

# %%
# b-beryllene_b

matters = [["β-beryllene", "3.5_phonon_dispersion_with_hydrogen_selected/b-beryllene_b", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene with Hydrogen (single side adhesion)", matters, y_range, None)
# plt.savefig("figures/3_phonon/3.32_phonon_b_h_phonopy.pdf")
# Out:
# {'β-beryllene': {'x': 0.6788651,
#   'freq_THz': -0.6074096355,
#   'backend': 'phonopy',
#   'directory': '3.5_phonon_dispersion_with_hydrogen_selected/b-beryllene_b'}}

# %%
# b-beryllene_bb

matters = [["β-beryllene", "3.5_phonon_dispersion_with_hydrogen_selected/b-beryllene_bb", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene with Hydrogen (double side adhesion)", matters, y_range, None)
# plt.savefig("figures/3_phonon/3.33_phonon_b_hh_phonopy.pdf")
# Out:
# {'β-beryllene': {'x': 0.0,
#   'freq_THz': -0.013110707,
#   'backend': 'phonopy',
#   'directory': '3.5_phonon_dispersion_with_hydrogen_selected/b-beryllene_bb'}}

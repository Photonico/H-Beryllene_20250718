# %% [markdown]
# # Band gap

# %%
# Prework

from vmatplot.bandstructure import *

# %%
# α-beryllene double side adhension

extract_bandgap_OUTCAR("4.0_bandstructure/a-beryllene_hh")
# Out:
# {'bandgap': -30.0791,
#  'HOMO index': 2,
#  'HOMO energy': 29.0,
#  'HOMO': 29.0,
#  'LUMO index': 3,
#  'LUMO energy': -1.0791,
#  'LUMO': -1.0791}

# %%
# β-beryllene single side adhension

extract_bandgap_OUTCAR("4.0_bandstructure/b-beryllene_h")
# Out:
# 'Error: OUTCAR not found in the specified directory.'

# %%
# β-beryllene double side adhension

extract_bandgap_OUTCAR("4.0_bandstructure/b-beryllene_hh")
# Out:
# 'Error: OUTCAR not found in the specified directory.'

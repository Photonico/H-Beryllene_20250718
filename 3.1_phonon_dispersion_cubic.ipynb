# %% [markdown]
# # Phonon dispersion for cubic family

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt

y_range = [-20, 30]

# %%
# cubic-Beryllene bulk

matters = [["c-Beryllene monolayer", "3.0_phonon_dispersion/c0-Beryllene_bulk_alt_5", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for cubic-Beryllene bulk", matters, y_range, None)
plt.savefig("figures/3.20_phonon_c-bulk.pdf")

# cell  k-points
# 3*3*3 27*27*27
# 4*4*4 7*7*7
# 5*5*5

# %%
# cubic-Beryllene monolayer

matters = [["c-Beryllene monolayer", "3.0_phonon_dispersion/c1-Beryllene_monolayer", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for cubic-Beryllene monolayer", matters, y_range, None)
plt.savefig("figures/3.21_phonon_c-monolayer.pdf")

# %%
# cubic-Beryllene bilayer

matters = [["c-Beryllene bilayer", "3.0_phonon_dispersion/c2-Beryllene_bilayer", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for cubic-Beryllene bilayer", matters, y_range, None)
plt.savefig("figures/3.22_phonon_c-bilayer.pdf")

# %%
# cubic-Beryllene trilayer

matters = [["c-Beryllene trilayer", "3.0_phonon_dispersion/c3-Beryllene_trilayer", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for cubic-Beryllene trilayer", matters, y_range, None)
plt.savefig("figures/3.23_phonon_c-trilayer.pdf")

# %%
# cubic-Beryllene quadlayer

matters = [["c-Beryllene quadlayer", "3.0_phonon_dispersion/c4-Beryllene_quadlayer", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for cubic-Beryllene quadlayer", matters, y_range, None)
plt.savefig("figures/3.24_phonon_c-quadlayer.pdf")

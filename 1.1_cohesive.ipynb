# %% [markdown]
# # Cohesive energy testing
#
# Cohesive energy versus parameters

# %%
# prework

from vmatplot.convergence import summarize_cohesive_energy, plot_cohesive_energy_parameters
import matplotlib.pyplot as plt

encut_boundary = (300, None)
kpoints_boundary = (12**2, None)

# %%
# cohesive energy versus energy cutoff

summarize_cohesive_energy("1.0_convergence/g-Beryllene_energycutoff","1.0_convergence/single_Beryllium")
g_encut = ["g-Beryllene monolayer", "1.0_convergence/g-Beryllene_energycutoff/cohesive_energy.dat", encut_boundary, "blue"]
encut_list = [g_encut]

plot_cohesive_energy_parameters("Cohesive energy versus energy cutoff for g-Beryllene monolayer", "encut", encut_list )
plt.savefig("figures/1.10_cohesive_encut.pdf")

# %%
# cohesive energy versus k-points for a-Beryllium

summarize_cohesive_energy("1.0_convergence/a0-Beryllium","1.0_convergence/single_Beryllium")
a_kpoints = ["α-Beryllium", "1.0_convergence/a0-Beryllium/cohesive_energy.dat", kpoints_boundary, "purple"]
kpoints_list = [a_kpoints]

plot_cohesive_energy_parameters("Cohesive energy versus k-points for α-Beryllium", "kpoints", kpoints_list)
plt.savefig("figures/1.11_cohesive_a-Beryllium.pdf")

# %%
# cohesive energy versus k-points for a-Beryllene

summarize_cohesive_energy("1.0_convergence/a1-Beryllene_monolayer","1.0_convergence/single_Beryllium")
a_kpoints = ["α-Beryllene monolayer", "1.0_convergence/a1-Beryllene_monolayer/cohesive_energy.dat", kpoints_boundary, "wine"]
kpoints_list = [a_kpoints]

plot_cohesive_energy_parameters("Cohesive energy versus k-points for α-Beryllene monolayer", "kpoints", kpoints_list)
plt.savefig("figures/1.12_cohesive_a-Beryllene.pdf")

# %%
# cohesive energy versus k-points for g-Beryllene

summarize_cohesive_energy("1.0_convergence/g-Beryllene_kpoints","1.0_convergence/single_Beryllium")
g_kpoints = ["g-Beryllene monolayer", "1.0_convergence/g-Beryllene_kpoints/cohesive_energy.dat", kpoints_boundary, "blue"]
kpoints_list = [g_kpoints]

plot_cohesive_energy_parameters("Cohesive energy versus k-points for g-Beryllene monolayer", "kpoints", kpoints_list)
plt.savefig("figures/1.13_cohesive_g-Beryllene.pdf")

# %%
# cohesive energy versus k-points for c-Beryllene bulk

# kpoints_boundary = (10**3, None)

summarize_cohesive_energy("1.0_convergence/c0-Beryllene_bulk","1.0_convergence/single_Beryllium")
t_kpoints = ["c-Beryllene bulk", "1.0_convergence/c0-Beryllene_bulk/cohesive_energy.dat", kpoints_boundary, "violet"]
kpoints_list = [t_kpoints]

plot_cohesive_energy_parameters("Cohesive energy versus k-points for c-Beryllene bulk", "kpoints", kpoints_list)
plt.savefig("figures/1.14_conv_c_bulk.pdf")

# %%
# cohesive energy versus k-points for c-Beryllene monolayer

summarize_cohesive_energy("1.0_convergence/c1-Beryllene_monolayer","1.0_convergence/single_Beryllium")
c_kpoints = ["c-Beryllene", "1.0_convergence/c1-Beryllene_monolayer/cohesive_energy.dat", kpoints_boundary, "lime"]
kpoints_list = [c_kpoints]

plot_cohesive_energy_parameters("Cohesive energy versus k-points for c-Beryllene monolayer", "kpoints", kpoints_list)
plt.savefig("figures/1.15_cohesive_c_monolayer.pdf")

# %%
# cohesive energy versus k-points for c-Beryllene bilayer

summarize_cohesive_energy("1.0_convergence/c2-Beryllene_bilayer","1.0_convergence/single_Beryllium")
t_kpoints = ["c-Beryllene bilayer", "1.0_convergence/c2-Beryllene_bilayer/cohesive_energy.dat", kpoints_boundary, "yellow"]
kpoints_list = [t_kpoints]

plot_cohesive_energy_parameters("Cohesive energy versus k-points for c-Beryllene trilayer", "kpoints", kpoints_list)
plt.savefig("figures/1.16_cohesive_c_bilayer.pdf")

# %%
# cohesive energy versus k-points for c-Beryllene trilayer

summarize_cohesive_energy("1.0_convergence/c3-Beryllene_trilayer","1.0_convergence/single_Beryllium")
t_kpoints = ["c-Beryllene trilayer", "1.0_convergence/c3-Beryllene_trilayer/cohesive_energy.dat", kpoints_boundary, "orange"]
kpoints_list = [t_kpoints]

plot_cohesive_energy_parameters("Cohesive energy versus k-points for c-Beryllene trilayer", "kpoints", kpoints_list)
plt.savefig("figures/1.17_cohesive_c_trilayer.pdf")
# Out:
# vasprun.xml in 1.0_convergence/c3-Beryllene_trilayer/441 is incomplete.

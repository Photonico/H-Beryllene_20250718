# %% [markdown]
# # Phonon dispersion
#
# for β-beryllene with Hydrogen Adhesion
#
# note:
#     * full hh3 = full hh2 ≈ full hh1
#     * full top ≈ full h1
#     * third th2 = third hh4
#     * third tt = third hh1

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt
y_range = [-10, 60]

# %%
# β-beryllene with full freqence top Hydrogen Adhesion

matters = [["top", "3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_t", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene (top)", matters, y_range, None)
# Out:
# {'top': {'x': 1.4957685997921861,
#   'freq_THz': -0.857478,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_t'}}

# %%
# β-beryllene with full freqence hollow Hydrogen Adhesion

matters = [["hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_h1", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene (hollow 1)", matters, y_range, None)
# Out:
# {'hollow': {'x': 1.4179805526511444,
#   'freq_THz': -0.91828,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_h1'}}

# %%
# β-beryllene with full freqence hollow Hydrogen Adhesion

matters = [["hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_h2", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene (hollow 2)", matters, y_range, None)
# Out:
# {'hollow': {'x': 0.019199716922754486,
#   'freq_THz': -0.433971,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_h2'}}

# %%
# β-beryllene with full freqence top-top Hydrogen Adhesion

matters = [["top-top", "3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_tt", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene (top-top)", matters, y_range, None)
# Out:
# {'top-top': {'x': 0.0,
#   'freq_THz': -0.01053,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_tt'}}

# %%
# β-beryllene with full freqence hollow-hollow Hydrogen Adhesion

matters = [["hollow-hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_hh1", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene (hollow-hollow 1)", matters, y_range, None)
# Out:
# {'hollow-hollow': {'x': 0.0,
#   'freq_THz': -0.00789,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_hh1'}}

# %%
# β-beryllene with full freqence hollow-hollow Hydrogen Adhesion

matters = [["hollow-hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_hh2", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene (hollow-hollow 2)", matters, y_range, None)
# Out:
# {'hollow-hollow': {'x': 0.03514129081208379,
#   'freq_THz': -0.398041,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_hh2'}}

# %%
# β-beryllene with full freqence hollow-hollow Hydrogen Adhesion

matters = [["hollow-hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_hh3", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene (hollow-hollow 3)", matters, y_range, None)
# Out:
# {'hollow-hollow': {'x': 0.0,
#   'freq_THz': -0.010796,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_hh3'}}

# %%
# β-beryllene with full freqence top-hollow Hydrogen Adhesion

matters = [["top-hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_th1", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene (top-hollow 1)", matters, y_range, None)
# Out:
# {'top-hollow': {'x': 0.0,
#   'freq_THz': -2.960407,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_th1'}}

# %%
# β-beryllene with full freqence top-hollow Hydrogen Adhesion

matters = [["top-hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_th2", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("β-beryllene (top-hollow 2)", matters, y_range, None)
# Out:
# {'top-hollow': {'x': 0.2770479463532225,
#   'freq_THz': -3.203343,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-beryllene_th2'}}

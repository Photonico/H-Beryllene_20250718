# %% [markdown]
# # Phonon dispersion
#
# for β-Beryllene with Hydrogen Adhesion
#
# note:
#     * full hh3 = full hh2 ≈ full hh1
#     * full top ≈ full h1
#     * third th2 = third hh4
#     * third tt = third hh1

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt
y_range = [-20, 30]

# %%
# β-Beryllene with full freqence top Hydrogen Adhesion

matters = [["full top", "3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_t", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full top)", matters, y_range, None)
# Out:
# {'full top': {'x': 1.472160683196365,
#   'freq_THz': -0.857478,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_t'}}

# %%
# β-Beryllene with full freqence hollow Hydrogen Adhesion

matters = [["full hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_h1", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow 1)", matters, y_range, None)
# Out:
# {'full hollow': {'x': 1.3921124449685918,
#   'freq_THz': -0.91828,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_h1'}}

# %%
# β-Beryllene with full freqence hollow Hydrogen Adhesion

matters = [["full hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_h2", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow 2)", matters, y_range, None)
# Out:
# {'full hollow': {'x': 0.015935165748589938,
#   'freq_THz': -0.433971,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_h2'}}

# %%
# β-Beryllene with full freqence top-top Hydrogen Adhesion

matters = [["full top-top", "3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_tt", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full top-top)", matters, y_range, None)
# Out:
# {'full top-top': {'x': 0.0,
#   'freq_THz': -0.01053,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_tt'}}

# %%
# β-Beryllene with full freqence hollow-hollow Hydrogen Adhesion

matters = [["full hollow-hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_hh1", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow-hollow 1)", matters, y_range, None)
# Out:
# {'full hollow-hollow': {'x': 0.0,
#   'freq_THz': -0.00789,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_hh1'}}

# %%
# β-Beryllene with full freqence hollow-hollow Hydrogen Adhesion

matters = [["full hollow-hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_hh2", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow-hollow 2)", matters, y_range, None)
# Out:
# {'full hollow-hollow': {'x': 0.029792220015477607,
#   'freq_THz': -0.398041,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_hh2'}}

# %%
# β-Beryllene with full freqence hollow-hollow Hydrogen Adhesion

matters = [["full hollow-hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_hh3", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full hollow-hollow 3)", matters, y_range, None)
# Out:
# {'full hollow-hollow': {'x': 0.0,
#   'freq_THz': -0.010796,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_hh3'}}

# %%
# β-Beryllene with full freqence top-hollow Hydrogen Adhesion

matters = [["full top-hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_th1", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full top-hollow 1)", matters, y_range, None)
# Out:
# {'full top-hollow': {'x': 0.0,
#   'freq_THz': -2.960407,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_th1'}}

# %%
# β-Beryllene with full freqence top-hollow Hydrogen Adhesion

matters = [["full top-hollow", "3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_th2", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion (full top-hollow 2)", matters, y_range, None)
# Out:
# {'full top-hollow': {'x': 0.22567833621069294,
#   'freq_THz': -3.203343,
#   'backend': 'vasp',
#   'directory': '3.2_phonon_dispersion_with_hydrogen_b/b-Beryllene_th2'}}

# %% [markdown]
# # Convergence testing
#
# Energy versus parameters

# %%
from vmatplot.convergence import *
import matplotlib.pyplot as plt

kpoints_boundary = (16, None)
encut_boundary = (250, None)

# %%
summarize_parameters("1.0_convergence/G-Beryllene_energycutoff")
g_Beryllene_encut = ["for g-Beryllene", "1.0_convergence/G-Beryllene_energycutoff/energy_parameters.dat", encut_boundary, "blue"]
materials = [g_Beryllene_encut]

plot_energy_parameters("Energy versus energy cutoff", "encut", materials)
plt.savefig("figures/1.0_encut.pdf")

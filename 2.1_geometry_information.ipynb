# %% [markdown]
# # Geometry information

# %%
# prework

from vmatplot.commons import identify_parameters
import matplotlib.pyplot as plt

# %%
# a-Beryllium

geometry_data = identify_parameters("2.4_self_consistent/a-Beryllium_k105")
lattice = geometry_data["lattice constant"]
kpoints = geometry_data["kpoints mesh"]
energy = geometry_data["total energy"]
time = geometry_data["elapsed time (sec)"]

print(f"For α-Beryllium bulk: \n k-points mesh: {kpoints}; \n lattice constant: {lattice}; \n total energy: {energy}; \n elapsed time: {time}.")
# Out:
# For α-Beryllium bulk:
#  k-points mesh: (105, 105, 105);
#  lattice constant: 2.2664238526360245;
#  total energy: -8.2432019;
#  elapsed time: 7443.709.

# %%
# a-beryllene monolayer

geometry_data = identify_parameters("2.4_self_consistent/a-beryllene")
lattice = geometry_data["lattice constant"]
kpoints = geometry_data["kpoints mesh"]
energy = geometry_data["total energy"]
time = geometry_data["elapsed time (sec)"]

print(f"For α-beryllene monolayer: \n k-points mesh: {kpoints}; \n lattice constant: {lattice}; \n total energy: {energy}; \n elapsed time: {time}.")
# Out:
# For α-beryllene monolayer:
#  k-points mesh: (27, 27, 1);
#  lattice constant: 2.1289827591301242;
#  total energy: -3.07850799;
#  elapsed time: 154.202.

# %%
# b-beryllene monolayer

geometry_data = identify_parameters("2.4_self_consistent/b-beryllene")
lattice = geometry_data["lattice constant"]
kpoints = geometry_data["kpoints mesh"]
energy = geometry_data["total energy"]
time = geometry_data["elapsed time (sec)"]

print(f"For β-beryllene monolayer: \n k-points mesh: {kpoints}; \n lattice constant: {lattice}; \n total energy: {energy}; \n elapsed time: {time}.")
# Out:
# For β-beryllene monolayer:
#  k-points mesh: (27, 27, 1);
#  lattice constant: 2.1469504557842742;
#  total energy: -7.03240019;
#  elapsed time: 251.753.

# %%
# g-beryllene monolayer

geometry_data = identify_parameters("2.4_self_consistent/g-beryllene_monolayer")
lattice = geometry_data["lattice constant"]
kpoints = geometry_data["kpoints mesh"]
energy = geometry_data["total energy"]
time = geometry_data["elapsed time (sec)"]

print(f"For g-beryllene monolayer: \n k-points mesh: {kpoints}; \n lattice constant: {lattice}; \n total energy: {energy}; \n elapsed time: {time}.")
# Out:
# For g-beryllene monolayer:
#  k-points mesh: (23, 23, 1);
#  lattice constant: 3.6485468756885324;
#  total energy: -3.44654853;
#  elapsed time: 91.542.

# %%
# c-Beryllium bulk

geometry_data = identify_parameters("2.4_self_consistent/c0-beryllene_bulk")
lattice = geometry_data["lattice constant"]
kpoints = geometry_data["kpoints mesh"]
energy = geometry_data["total energy"]
time = geometry_data["elapsed time (sec)"]

print(f"For c-Beryllium bulk: \n k-points mesh: {kpoints}; \n lattice constant: {lattice}; \n total energy: {energy}; \n elapsed time: {time}.")
# Out:
# For c-beryllene bulk:
#  k-points mesh: (27, 27, 27);
#  lattice constant: 2.1663874890984025;
#  total energy: -4.02479624;
#  elapsed time: 76.621.

# %%
# c-beryllene trilayer

geometry_data = identify_parameters("2.4_self_consistent/c3-beryllene_trilayer")
lattice = geometry_data["lattice constant"]
kpoints = geometry_data["kpoints mesh"]
energy = geometry_data["total energy"]
time = geometry_data["elapsed time (sec)"]

print(f"For c-beryllene trilayer: \n k-points mesh: {kpoints}; \n lattice constant: {lattice}; \n total energy: {energy}; \n elapsed time: {time}.")
# Out:
# For c-beryllene trilayer:
#  k-points mesh: (25, 25, 1);
#  lattice constant: 2.18374554;
#  total energy: -10.6883581;
#  elapsed time: 144.502.

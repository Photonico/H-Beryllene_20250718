# %% [markdown]
# # Geometry optimization
#
# Energy versus parameters
#
# * VASP parameters:
#
# `ISIF = 3`

# %%
# prework

from vmatplot.commons import identify_parameters
import matplotlib.pyplot as plt

# %%
# a-Beryllium bulk

geometry_data = identify_parameters("2.0_geometry_optimization/a-Beryllium")
lattice = geometry_data["lattice constant"]

print(f"For α-Beryllium bulk, the optimizated lattice constant is {lattice}")
# Out:
# For α-Beryllium bulk, the optimizated lattice constant is 2.2664238526360245

# %%
# a-beryllene monolayer

geometry_data = identify_parameters("2.0_geometry_optimization/a-beryllene")
lattice = geometry_data["lattice constant"]

print(f"For α-beryllene monolayer, the optimizated lattice constant is {lattice}")

# old: For α-beryllene monolayer, the optimizated lattice constant is 2.12889052
# ole: For α-beryllene monolayer, the optimizated lattice constant is 2.1289827591301242
# new: For α-beryllene monolayer, the optimizated lattice constant is 2.1289827591301242
# Out:
# For α-beryllene monolayer, the optimizated lattice constant is 2.1289827591301242

# %%
# b-beryllene monolayer

geometry_data = identify_parameters("2.0_geometry_optimization/b-beryllene")
lattice = geometry_data["lattice constant"]

print(f"For β-beryllene monolayer, the optimizated lattice constant is {lattice}")
# Out:
# For β-beryllene monolayer, the optimizated lattice constant is 2.1469504557842742

# %%
# g-beryllene monolayer

geometry_data = identify_parameters("2.0_geometry_optimization/g-beryllene_monolayer")
lattice = geometry_data["lattice constant"]

print(f"For g-beryllene monolayer, the optimizated lattice constant is {lattice}")
# Out:
# For g-beryllene monolayer, the optimizated lattice constant is 3.6485468756885324

# %%
# c-beryllene bulk

geometry_data = identify_parameters("2.0_geometry_optimization/c0-Beryllium")
lattice = geometry_data["lattice constant"]

print(f"For c-beryllene bulk, the optimizated lattice constant is {lattice}")
# Out:
# For c-beryllene bulk, the optimizated lattice constant is 2.1663874890984025

# %%
# c-beryllene monolayer

geometry_data = identify_parameters("2.0_geometry_optimization/c1-beryllene_monolayer")
lattice = geometry_data["lattice constant"]

print(f"For c-beryllene monolayer, the optimizated lattice constant is {lattice}")
# Out:
# For c-beryllene monolayer, the optimizated lattice constant is 1.99725667

# %%
# c-beryllene bilayer

geometry_data = identify_parameters("2.0_geometry_optimization/c2-beryllene_bilayer")
lattice = geometry_data["lattice constant"]

print(f"For c-beryllene bilayer, the optimizated lattice constant is {lattice}")
# Out:
# For c-beryllene bilayer, the optimizated lattice constant is 2.09597

# %%
# c-beryllene trilayer

geometry_data = identify_parameters("2.0_geometry_optimization/c3-beryllene_trilayer")
lattice = geometry_data["lattice constant"]

print(f"For c-beryllene trilayer, the optimizated lattice constant is {lattice}")
# Out:
# For c-beryllene trilayer, the optimizated lattice constant is 2.18374554

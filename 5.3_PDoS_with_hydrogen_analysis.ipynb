# %% [markdown]
# # Projected Density of State Analysis

# %%
# prework

from vmatplot.commons import get_elements, get_elements_coordinates

# %%
directory = "5.0_PDoS/a-Beryllene_hh"
elements = get_elements(directory)
print("α Beryllene hollow-hollow:", elements)
# Out:
# α Beryllene hollow-hollow: {'Be': (1, 1), 'H': (2, 3)}

# %%
directory = "5.0_PDoS/b-Beryllene_h"
elements = get_elements(directory)
print("β Beryllene hollow:", elements)
# Out:
# β Beryllene hollow: {'Be': (1, 2), 'H': (3, 3)}

# %%
directory = "5.0_PDoS/b-Beryllene_hh"
elements = get_elements(directory)
print("β Beryllene hollow-hollow:", elements)
# Out:
# β Beryllene hollow-hollow: {'Be': (1, 2), 'H': (3, 4)}

# %% [markdown]
# # Band structure

# %%
# prework

from vmatplot.bandstructure import plot_bandstructure
import matplotlib.pyplot as plt

# %%
# α-Beryllene_hh

bs_list = [["monocolor", "α-Beryllene", "4.0_bandstructure/a-Beryllene_hh", "blue"]]

plot_bandstructure("α-Beryllene with Hydrogen (double side adhesion)", bs_list, (-8,8))
plt.savefig("figures/4_bs/4.31_BS_a_hh.pdf")

# %%
# β-Beryllene_b

bs_list = [["monocolor", "β-Beryllene", "4.0_bandstructure/b-Beryllene_b", "blue"]]

plot_bandstructure("β-Beryllene with Hydrogen (single side adhesion)", bs_list, (-8,8))
plt.savefig("figures/4_bs/4.32_BS_b_b.pdf")

# %%
# β-Beryllene_b alt

bs_list = [["monocolor", "β-Beryllene", "4.0_bandstructure/b-Beryllene_b_alt/2_Bands", "blue"]]

plot_bandstructure("β-Beryllene with Hydrogen (single side adhesion)", bs_list, (-8,8))
plt.savefig("figures/4_bs/4.32_BS_b_b.pdf")

# %%
# β-Beryllene_bb

bs_list = [["monocolor", "β-Beryllene", "4.0_bandstructure/b-Beryllene_bb", "blue"]]

plot_bandstructure("β-Beryllene with Hydrogen (double side adhesion)", bs_list, (-8,8))
plt.savefig("figures/4_bs/4.33_BS_b_bb.pdf")

# %%
# β-Beryllene_bb alt

bs_list = [["monocolor", "β-Beryllene", "4.0_bandstructure/b-Beryllene_bb_alt/2_Bands", "blue"]]

plot_bandstructure("β-Beryllene with Hydrogen (double side adhesion)", bs_list, (-8,8))
plt.savefig("figures/4_bs/4.33_BS_b_bb_alt.pdf")

# %% [markdown]
# # Phonon dispersion
#
# for cubic beryllene trilayer with Hydrogen Adhesion
#
# note:
#
# cubic-beryllene full top-hollow: become a hex family system

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt
y_range = [-20, 50]

# %%
# cubic beryllene trilayer with full freqence top Hydrogen Adhesion

matters = [["top", "3.3_phonon_dispersion_with_hydrogen_c/c-beryllene_t", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("cubic beryllene trilayer (top)", matters, y_range, None)
# Out:
# {'top': {'x': 1.1502628698801847,
#   'freq_THz': -19.487679,
#   'backend': 'vasp',
#   'directory': '3.3_phonon_dispersion_with_hydrogen_c/c-beryllene_t'}}

# %%
# cubic beryllene trilayer with full freqence hollow Hydrogen Adhesion

matters = [["hollow", "3.3_phonon_dispersion_with_hydrogen_c/c-beryllene_h", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("cubic beryllene trilayer (hollow)", matters, y_range, None)
# Out:
# {'hollow': {'x': 0.0,
#   'freq_THz': -41.377918,
#   'backend': 'vasp',
#   'directory': '3.3_phonon_dispersion_with_hydrogen_c/c-beryllene_h'}}

# %%
# cubic beryllene trilayer with full freqence top-top Hydrogen Adhesion

matters = [["top-top", "3.3_phonon_dispersion_with_hydrogen_c/c-beryllene_tt", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("cubic beryllene trilayer (top-top)", matters, y_range, None)
# Out:
# {'top-top': {'x': 1.123079776905375,
#   'freq_THz': -19.711668,
#   'backend': 'vasp',
#   'directory': '3.3_phonon_dispersion_with_hydrogen_c/c-beryllene_tt'}}

# %%
# cubic beryllene trilayer with full freqence hollow-hollow Hydrogen Adhesion

matters = [["hollow-hollow", "3.3_phonon_dispersion_with_hydrogen_c/c-beryllene_hh", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("cubic beryllene trilayer (hollow-hollow)", matters, y_range, None)
# Out:
# {'hollow-hollow': {'x': 1.1497855930067755,
#   'freq_THz': -46.541768,
#   'backend': 'vasp',
#   'directory': '3.3_phonon_dispersion_with_hydrogen_c/c-beryllene_hh'}}

# %%
# cubic beryllene trilayer with full freqence top-hollow Hydrogen Adhesion

matters = [["top-hollow", "3.3_phonon_dispersion_with_hydrogen_c/c-beryllene_th", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("cubic beryllene trilayer (top-hollow)", matters, y_range, None)
# Out:
# {'top-hollow': {'x': 0.0,
#   'freq_THz': -35.408622,
#   'backend': 'vasp',
#   'directory': '3.3_phonon_dispersion_with_hydrogen_c/c-beryllene_th'}}

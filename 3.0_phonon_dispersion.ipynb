# %% [markdown]
# # Phonon dispersion

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt

# %%
# Phonon dispersion a- g-

matters = [
           ["α-Beryllene monolayer", "3.0_phonon_dispersion/a1-Beryllene_monolayer_monolayer", "purple", "solid", 1.5, 1.0, 0],
           ["g-Beryllene monolayer", "3.0_phonon_dispersion/g-Beryllene_monolayer", "blue", "solid", 1.5, 1.0, 0]
           ]

plot_phonons("Phonon dispersion", matters, [-2,18], "upper right")
plt.savefig("figures/3.10_phonon_ag_layers.pdf")

# %%
# Phonon dispersion c-

matters = [
         #   ["c-Beryllene bulk", "3.0_phonon_dispersion/c0-Beryllene_bulk", "cyan", "solid", 1.5, 1.0, 0],
           ["c-Beryllene monolayer", "3.0_phonon_dispersion/c1-Beryllene_monolayer", "lime", "solid", 1.5, 1.0, 0],
           ["c-Beryllene bilayer", "3.0_phonon_dispersion/c2-Beryllene_bilayer", "yellow", "solid", 1.5, 1.0, 0],
           ["c-Beryllene trilayer", "3.0_phonon_dispersion/c3-Beryllene_trilayer", "orange", "solid", 1.5, 1.0, 0],
           ]

plot_phonons("Phonon dispersion", matters, [-2,18], "upper right")
plt.savefig("figures/3.11_phonon_c_layers.pdf")

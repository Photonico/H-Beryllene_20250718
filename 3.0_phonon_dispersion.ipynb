# %% [markdown]
# # Phonon dispersion

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt

y_range = [-20, 30]

# %%
# α-Beryllene monolayer

matters = [["α-Beryllene monolayer", "3.0_phonon_dispersion/a1-Beryllene_monolayer_alt", "violet", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for α-Beryllene monolayer", matters, y_range, None)
plt.savefig("figures/3.12_phonon_a-Beryllene.pdf")

# %%
# g-Beryllene monolayer

matters = [["g-Beryllene monolayer", "3.0_phonon_dispersion/g-Beryllene_monolayer_5", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for g-Beryllene monolayer", matters, y_range, None)
plt.savefig("figures/3.13_phonon_g-Beryllene.pdf")

# %%
# c-Beryllene bulk

matters = [["c-Beryllene bulk", "3.0_phonon_dispersion/c0-Beryllene_bulk", "cyan", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for cubic Beryllene bulk", matters, y_range, None)
plt.savefig("figures/3.15_phonon_c_monolayer.pdf")

# %%
# c-Beryllene monolayer

matters = [["c-Beryllene monolayer", "3.0_phonon_dispersion/c1-Beryllene_monolayer", "lime", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for cubic Beryllene monolayer", matters, y_range, None)
plt.savefig("figures/3.15_phonon_c_monolayer.pdf")

# %%
# c-Beryllene bilayer

matters = [["c-Beryllene bilayer", "3.0_phonon_dispersion/c2-Beryllene_bilayer", "yellow", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for cubic Beryllene bilayer", matters, y_range, None)
plt.savefig("figures/3.16_phonon_c_bilayer.pdf")

# %%
# c-Beryllene trilayer

matters = [["c-Beryllene trilayer", "3.0_phonon_dispersion/c3-Beryllene_trilayer", "orange", "solid", 1.5, 1.0, 0],]

plot_phonons("Phonon dispersion for cubic Beryllene trilayer", matters, y_range, None)
plt.savefig("figures/3.17_phonon_c_trilayer.pdf")

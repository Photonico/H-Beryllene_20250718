# %% [markdown]
# # Phonon dispersion

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt

# %%
# Phonon dispersion alpha

dendotted = (0,(1,1))

matters = [["α-Beryllene monolayer", "3.0_phonon_dispersion/a-Beryllene", "purple", "solid", 1.5, 1.0, 0],
           ["g-Beryllene monolayer", "3.0_phonon_dispersion/g-Beryllene", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion", matters, [-2,8], "upper right")
plt.savefig("figures/3.10_phonon_ag.pdf")

# %% [markdown]
# # Density of State

# %%
# prework

from vmatplot.dos import plot_dos
import matplotlib.pyplot as plt

# %%
# overview DoS

systems = [["α-Beryllene",                          "5.0_PDoS/a-Beryllene",         "unpolarized",          "blue"],
           ["α-Beryllene (both side H-terminated)", "5.0_PDoS/a-Beryllene_hh",      "unpolarized",          "violet"],
           ["β-Beryllene",                          "5.0_PDoS/b-Beryllene",         "unpolarized",          "lime"],
           ["β-Beryllene (single side H-terminated)",   "5.0_PDoS/b-Beryllene_h",       "unpolarized",          "yellow"],
           ["β-Beryllene (both side H-terminated)",     "5.0_PDoS/b-Beryllene_hh",      "unpolarized",          "orange"],
           ]

plot_dos("DoS", systems, 8, [0, 5], "Total")
plt.savefig("figures/5_dos/5.30_DoS_hydrogen.pdf")

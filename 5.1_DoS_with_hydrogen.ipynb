# %% [markdown]
# # Density of State

# %%
# prework

from vmatplot.dos import plot_dos
import matplotlib.pyplot as plt

# %%
# overview DoS

systems = [["α-Beryllene",              "5.0_PDoS/a-Beryllene",         "unpolarized",          "blue"],
           ["2H-terminated α-Beryllene","5.0_PDoS/a-Beryllene_hh",      "unpolarized",          "violet"],
           ["β-Beryllene",              "5.0_PDoS/b-Beryllene",         "unpolarized",          "lime"],
           ["H-terminated β-Beryllene", "5.0_PDoS/b-Beryllene_b",       "unpolarized",          "yellow"],
           ["2H-terminated β-Beryllene","5.0_PDoS/b-Beryllene_bb",      "unpolarized",          "orange"],
           ]

plot_dos("Total DoS", systems, 8, [0, 3.5], "Total")
plt.savefig("figures/5_dos/5.30_DoS_hydrogen.pdf")
plt.savefig("figures_for_publication/fig3.12a_Total_DoS.pdf")

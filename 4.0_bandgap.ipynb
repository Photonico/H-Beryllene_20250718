# %% [markdown]
# # Band gap

# %%
# Prework

from vmatplot.bandstructure import *

# %%
# α-Beryllium bulk

extract_bandgap_OUTCAR("4.0_bandstructure/a-Beryllium")
# Out:
# {'bandgap': -28.22364,
#  'HOMO index': 2,
#  'HOMO energy': 30.22364,
#  'HOMO': 30.22364,
#  'LUMO index': 3,
#  'LUMO energy': 2.0,
#  'LUMO': 2.0}

# %%
# α-Beryllene

extract_bandgap_OUTCAR("4.0_bandstructure/a-Beryllene")
# Out:
# {'bandgap': -47.6161739,
#  'HOMO index': 1,
#  'HOMO energy': 42.0,
#  'HOMO': 42.0,
#  'LUMO index': 2,
#  'LUMO energy': -5.6161739,
#  'LUMO': -5.6161739}

# %%
# β-Beryllene

extract_bandgap_OUTCAR("4.0_bandstructure/b-Beryllene")
# Out:
# {'bandgap': -33.2362,
#  'HOMO index': 2,
#  'HOMO energy': 29.0,
#  'HOMO': 29.0,
#  'LUMO index': 3,
#  'LUMO energy': -4.2362,
#  'LUMO': -4.2362}

# %%
# cubic Beryllium

extract_bandgap_OUTCAR("4.0_bandstructure/c0-Beryllium")
# Out:
# {'bandgap': -32.8278259,
#  'HOMO index': 1,
#  'HOMO energy': 27.211652,
#  'HOMO': 27.211652,
#  'LUMO index': 2,
#  'LUMO energy': -5.6161739,
#  'LUMO': -5.6161739}

# %%
# cubic Beryllene trilayer

extract_bandgap_OUTCAR("4.0_bandstructure/c3-Beryllene_trilayer")
# Out:
# {'bandgap': -132.4863,
#  'HOMO index': 3,
#  'HOMO energy': 128.0,
#  'HOMO': 128.0,
#  'LUMO index': 4,
#  'LUMO energy': -4.4863,
#  'LUMO': -4.4863}

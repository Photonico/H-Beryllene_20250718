# %% [markdown]
# # Dielectric function convergence test
#
# Optical normalization uses the relaxed structure of each calculation and the original surface-radius convention (Be: 1.98 Å; H: 0.70 Å). Hydrogenated slabs use the species at the outermost atomic centres; this convention is not a union of atomic spheres. Both xx and zz retain the same effective-volume normalization. Absorption is reported in nm$^{-1}$ with $\omega=2\pi E/h$. These are effective-thickness IPA interband spectra; no Drude term is added. Scalar reflectivity uses the semi-infinite-medium expression, not a finite-sheet measurement model.

# %%
# Prework

from vmatplot.dielectric_function import *
from vmatplot.structure import slab_optical_factor
from vmatplot.plot_validation import ensure_curve_visibility
import matplotlib.pyplot as plt

# Optical factors from each relaxed structure; radii: Be = 1.98 A, H = 0.70 A.
# The cell height is the full surface-normal period, not the vacuum gap.
factor_bulk = (1, 1)                                        # for α-Beryllium and cubic Beryllium bulk

data_boundary = (-50, 50)

# %%
# α-Beryllium nbands

systems = [
           ["NBANDS = 210",   "6.0_dielectric_function/a-Beryllium_192_k27",  "violet", None,None,None, factor_bulk],
           ["NBANDS = 168",   "6.0_dielectric_function/a-Beryllium_128_k27",  "blue",   None,None,None, factor_bulk],
           ["NBANDS = 126",   "6.0_dielectric_function/a-Beryllium_96_k27",   "lime",   None,None,None, factor_bulk],
           ["NBANDS = 42",    "6.0_dielectric_function/a-Beryllium_32_k27",   "orange", None,None,None, factor_bulk],
           ["selected",     "6.0_dielectric_selection/a-Beryllium",         "wine",   None,None,None, factor_bulk],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for bulk hcp beryllium", systems, components, "hor", True, "eV", (0,10), data_boundary, True)
ensure_curve_visibility(plt.gcf())
plt.savefig("figures/6_dielectric_test/6.10_dielec_a-Beryllium_nbands.pdf")
ensure_curve_visibility(plt.gcf())
plt.savefig("figures_for_publication/S3.3_dielec_hcp.pdf")

# %%
# α-Beryllium k-points

systems = [
           ["(75, 75, 75)", "6.0_dielectric_function/a-Beryllium_64_k75",   "violet",   None,None,None, factor_bulk],
           ["(45, 45, 45)", "6.0_dielectric_function/a-Beryllium_64_k45",   "blue",     None,None,None, factor_bulk],
           ["(27, 27, 27)", "6.0_dielectric_function/a-Beryllium_64_k27",   "lime",     None,None,None, factor_bulk],
           ["(15, 15, 15)", "6.0_dielectric_function/a-Beryllium_64_k15",   "orange",   None,None,None, factor_bulk],
           ["selected",     "6.0_dielectric_selection/a-Beryllium",         "wine",     None,None,None, factor_bulk],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for bulk hcp beryllium", systems, components, "hor", True, "eV", (0,10), data_boundary, True)
ensure_curve_visibility(plt.gcf())
plt.savefig("figures/6_dielectric_test/6.10_dielec_a-Beryllium_kpoints.pdf")
ensure_curve_visibility(plt.gcf())
plt.savefig("figures_for_publication/S3.4_dielec_hcp.pdf")

# %%
# α-beryllene

systems = [
           ["NBANDS = 294",   "6.0_dielectric_function/a-Beryllene_256_k27",  "violet",   None,None,None, slab_optical_factor("6.0_dielectric_function/a-Beryllene_256_k27")],
           ["NBANDS = 210",   "6.0_dielectric_function/a-Beryllene_192_k27",  "blue",     None,None,None, slab_optical_factor("6.0_dielectric_function/a-Beryllene_192_k27")],
           ["NBANDS = 168",   "6.0_dielectric_function/a-Beryllene_128_k27",  "green",    None,None,None, slab_optical_factor("6.0_dielectric_function/a-Beryllene_128_k27")],
           ["NBANDS = 98",    "6.0_dielectric_function/a-Beryllene_96_k27",   "lime",     None,None,None, slab_optical_factor("6.0_dielectric_function/a-Beryllene_96_k27")],
           ["NBANDS = 84",    "6.0_dielectric_function/a-Beryllene_64_k27",   "orange",   None,None,None, slab_optical_factor("6.0_dielectric_function/a-Beryllene_64_k27")],
           ["selected",     "6.0_dielectric_selection/a-Beryllene",         "wine",     None,None,None, slab_optical_factor("6.0_dielectric_selection/a-Beryllene")],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]
data_boundary = (-4, 20)

plot_dielectric_function("Dielectric function for α-beryllene", systems, components, "hor", True, "eV", (0,10), data_boundary, True)
ensure_curve_visibility(plt.gcf())
plt.savefig("figures/6_dielectric_test/6.11_dielec_a-Beryllene_nbands.pdf")
ensure_curve_visibility(plt.gcf())
plt.savefig("figures_for_publication/S3.5_dielec_alpha.pdf")

# %%
# α-beryllene k-points

systems = [
           ["(105, 105, 1)", "6.0_dielectric_function/a-Beryllene_96_k105", "purple",   None,None,None, slab_optical_factor("6.0_dielectric_function/a-Beryllene_96_k105")],
           ["(75, 75, 1)", "6.0_dielectric_function/a-Beryllene_96_k75",    "violet",   None,None,None, slab_optical_factor("6.0_dielectric_function/a-Beryllene_96_k75")],
           ["(45, 45, 1)", "6.0_dielectric_function/a-Beryllene_96_k45",    "blue",     None,None,None, slab_optical_factor("6.0_dielectric_function/a-Beryllene_96_k45")],
           ["(27, 27, 1)", "6.0_dielectric_function/a-Beryllene_96_k27",    "lime",     None,None,None, slab_optical_factor("6.0_dielectric_function/a-Beryllene_96_k27")],
           ["(15, 15, 1)", "6.0_dielectric_function/a-Beryllene_96_k15",    "orange",   None,None,None, slab_optical_factor("6.0_dielectric_function/a-Beryllene_96_k15")],
           ["selected",     "6.0_dielectric_selection/a-Beryllene",         "wine",     None,None,None, slab_optical_factor("6.0_dielectric_selection/a-Beryllene")],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]
data_boundary = (-5, 20)

plot_dielectric_function("Dielectric function for α-beryllene", systems, components, "hor", True, "eV", (4,8), data_boundary, True)
ensure_curve_visibility(plt.gcf())
plt.savefig("figures/6_dielectric_test/6.11_dielec_a-Beryllene_kpoints.pdf")
ensure_curve_visibility(plt.gcf())
plt.savefig("figures_for_publication/S3.6_dielec_alpha.pdf")

# %%
# β-beryllene

systems = [
           ["NBANDS = 294",   "6.0_dielectric_function/b-Beryllene_256_k27",  "violet",   None,None,None, slab_optical_factor("6.0_dielectric_function/b-Beryllene_256_k27")],
           ["NBANDS = 210",   "6.0_dielectric_function/b-Beryllene_192_k27",  "blue",     None,None,None, slab_optical_factor("6.0_dielectric_function/b-Beryllene_192_k27")],
           ["NBANDS = 168",   "6.0_dielectric_function/b-Beryllene_128_k27",  "green",    None,None,None, slab_optical_factor("6.0_dielectric_function/b-Beryllene_128_k27")],
           ["NBANDS = 98",    "6.0_dielectric_function/b-Beryllene_96_k27",   "lime",     None,None,None, slab_optical_factor("6.0_dielectric_function/b-Beryllene_96_k27")],
           ["NBANDS = 84",    "6.0_dielectric_function/b-Beryllene_64_k27",   "orange",   None,None,None, slab_optical_factor("6.0_dielectric_function/b-Beryllene_64_k27")],
           ["selected",     "6.0_dielectric_selection/b-Beryllene",         "wine",     None,None,None, slab_optical_factor("6.0_dielectric_selection/b-Beryllene")],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]
data_boundary= (-20,40)

plot_dielectric_function("Dielectric function for β-beryllene", systems, components, "hor", True, "eV", (0,10), data_boundary, True)
ensure_curve_visibility(plt.gcf())
plt.savefig("figures/6_dielectric_test/6.12_dielec_b-Beryllene_nbands.pdf")
ensure_curve_visibility(plt.gcf())
plt.savefig("figures_for_publication/S3.7_dielec_beta.pdf")

# %%
# β-beryllene

systems = [
           ["(105, 105, 1)", "6.0_dielectric_function/b-Beryllene_96_k105", "purple",   None,None,None, slab_optical_factor("6.0_dielectric_function/b-Beryllene_96_k105")],
           ["(75, 75, 1)", "6.0_dielectric_function/b-Beryllene_96_k75",    "violet",   None,None,None, slab_optical_factor("6.0_dielectric_function/b-Beryllene_96_k75")],
           ["(45, 45, 1)", "6.0_dielectric_function/b-Beryllene_96_k45",    "blue",     None,None,None, slab_optical_factor("6.0_dielectric_function/b-Beryllene_96_k45")],
           ["(27, 27, 1)", "6.0_dielectric_function/b-Beryllene_96_k27",    "lime",     None,None,None, slab_optical_factor("6.0_dielectric_function/b-Beryllene_96_k27")],
           ["(15, 15, 1)", "6.0_dielectric_function/b-Beryllene_96_k15",    "orange",   None,None,None, slab_optical_factor("6.0_dielectric_function/b-Beryllene_96_k15")],
           ["selected",    "6.0_dielectric_selection/b-Beryllene",          "wine",     None,None,None, slab_optical_factor("6.0_dielectric_selection/b-Beryllene")],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]
data_boundary = (-20,35)

plot_dielectric_function("Dielectric function for β-beryllene", systems, components, "hor", True, "eV", (0,10), data_boundary, True)
ensure_curve_visibility(plt.gcf())
plt.savefig("figures/6_dielectric_test/6.12_dielec_b-Beryllene_kpoints.pdf")
ensure_curve_visibility(plt.gcf())
plt.savefig("figures_for_publication/S3.8_dielec_beta.pdf")

# %%
# cubic Beryllium nbands

systems = [
           ["NBANDS = 168",   "6.0_dielectric_function/c0-Beryllium_128_k27",     "violet", None,None,None, factor_bulk],
           ["NBANDS = 126",   "6.0_dielectric_function/c0-Beryllium_96_k27",      "blue",   None,None,None, factor_bulk],
           ["NBANDS = 70",    "6.0_dielectric_function/c0-Beryllium_64_k27",      "lime",   None,None,None, factor_bulk],
           ["NBANDS = 42",    "6.0_dielectric_function/c0-Beryllium_32_k27",      "orange", None,None,None, factor_bulk],
           ["selected",     "6.0_dielectric_selection/c0-Beryllium",            "wine",   None,None,None, factor_bulk],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]
data_boundary= (-10,40)

plot_dielectric_function("Dielectric function for bulk bcc beryllium", systems, components, "hor", True, "eV", (0,10), data_boundary, True)
ensure_curve_visibility(plt.gcf())
plt.savefig("figures/6_dielectric_test/6.20_dielec_c-Beryllium_nbands.pdf")
ensure_curve_visibility(plt.gcf())
plt.savefig("figures_for_publication/S3.9_dielec_bcc.pdf")

# %%
# cubic Beryllium k-points

systems = [
           ["(75, 75, 75)", "6.0_dielectric_function/c0-Beryllium_64_k75",  "violet",   None,None,None, factor_bulk],
           ["(45, 45, 45)", "6.0_dielectric_function/c0-Beryllium_64_k45",  "blue",     None,None,None, factor_bulk],
           ["(27, 27, 27)", "6.0_dielectric_function/c0-Beryllium_64_k27",  "lime",     None,None,None, factor_bulk],
           ["(15, 15, 15)", "6.0_dielectric_function/c0-Beryllium_64_k15",  "orange",   None,None,None, factor_bulk],
           ["selected",     "6.0_dielectric_selection/c0-Beryllium",        "wine",     None,None,None, factor_bulk],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for bulk bcc beryllium", systems, components, "hor", True, "eV", (0,10), data_boundary, True)
ensure_curve_visibility(plt.gcf())
plt.savefig("figures/6_dielectric_test/6.20_dielec_c-Beryllium_kpoints.pdf")
ensure_curve_visibility(plt.gcf())
plt.savefig("figures_for_publication/S3.10_dielec_bcc.pdf")

# %%
# cubic beryllene trilayer

systems = [
           ["NBANDS = 294",   "6.0_dielectric_function/c3-Beryllene_256_k25",     "violet",    None,None,None, slab_optical_factor("6.0_dielectric_function/c3-Beryllene_256_k25")],
           ["NBANDS = 210",   "6.0_dielectric_function/c3-Beryllene_192_k25",     "blue",      None,None,None, slab_optical_factor("6.0_dielectric_function/c3-Beryllene_192_k25")],
           ["NBANDS = 168",   "6.0_dielectric_function/c3-Beryllene_128_k25",     "green",     None,None,None, slab_optical_factor("6.0_dielectric_function/c3-Beryllene_128_k25")],
           ["NBANDS = 126",   "6.0_dielectric_function/c3-Beryllene_96_k25",      "lime",      None,None,None, slab_optical_factor("6.0_dielectric_function/c3-Beryllene_96_k25")],
           ["NBANDS = 84",    "6.0_dielectric_function/c3-Beryllene_64_k25",      "orange",    None,None,None, slab_optical_factor("6.0_dielectric_function/c3-Beryllene_64_k25")],
           ["selected",     "6.0_dielectric_selection/c3-Beryllene",            "wine",      None,None,None, slab_optical_factor("6.0_dielectric_selection/c3-Beryllene")],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]
data_boundary = (-10,30)

plot_dielectric_function("Dielectric function for cubic beryllene trilayer", systems, components, "hor", True, "eV", (0,10), data_boundary, True)
ensure_curve_visibility(plt.gcf())
plt.savefig("figures/6_dielectric_test/6.21_dielec_c-Beryllene_trilayer_nbands.pdf")
ensure_curve_visibility(plt.gcf())
plt.savefig("figures_for_publication/S3.11_dielec_cubic.pdf")

# %%
# cubic beryllene trilayer

systems = [
           ["(105, 105, 1)", "6.0_dielectric_function/c3-Beryllene_96_k105","purple",   None,None,None, slab_optical_factor("6.0_dielectric_function/c3-Beryllene_96_k105")],
           ["(75, 75, 1)", "6.0_dielectric_function/c3-Beryllene_96_k75",   "violet",   None,None,None, slab_optical_factor("6.0_dielectric_function/c3-Beryllene_96_k75")],
           ["(45, 45, 1)", "6.0_dielectric_function/c3-Beryllene_96_k45",   "blue",     None,None,None, slab_optical_factor("6.0_dielectric_function/c3-Beryllene_96_k45")],
           ["(27, 27, 1)", "6.0_dielectric_function/c3-Beryllene_96_k27",   "lime",     None,None,None, slab_optical_factor("6.0_dielectric_function/c3-Beryllene_96_k27")],
           ["(15, 15, 1)", "6.0_dielectric_function/c3-Beryllene_96_k15",   "orange",   None,None,None, slab_optical_factor("6.0_dielectric_function/c3-Beryllene_96_k15")],
           ["selected",    "6.0_dielectric_selection/c3-Beryllene",         "wine",     None,None,None, slab_optical_factor("6.0_dielectric_selection/c3-Beryllene")],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]
data_boundary = (-15,30)

plot_dielectric_function("Dielectric function for cubic beryllene trilayer", systems, components, "hor", True, "eV", (0,10), data_boundary, True)
ensure_curve_visibility(plt.gcf())
plt.savefig("figures/6_dielectric_test/6.21_dielec_c-Beryllene_trilayer_kpoints.pdf")
ensure_curve_visibility(plt.gcf())
plt.savefig("figures_for_publication/S3.12_dielec_cubic.pdf")

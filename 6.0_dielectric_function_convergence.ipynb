# %% [markdown]
# # Dielectric function convergence test

# %%
# Prework

from vmatplot.dielectric_function import *
import matplotlib.pyplot as plt

# system factors (d_c, (z_max-z_min)*d_c+2*r_be) r_be = 1.98
factor_bulk = (1, 1)                                        # for α-Beryllium and cubic Beryllium bulk
factor_a = (40, 2*1.98)                                     # for α-Beryllene monolayer
factor_b = (40, 0.0473771641975619+2*1.98)                  # for β-Beryllene monolayer
factor_c = (40, 0.0751622445053417+2*1.98)                  # for cubic Beryllene trilayer

data_boundary = (-60, 60)

# %%
# α-Beryllium nbands

systems = [["192 nbands",   "6.0_dielectric_function/a-Beryllium_192",      "purple", None,None,None, factor_bulk],
           ["160 nbands",   "6.0_dielectric_function/a-Beryllium_160",      "violet", None,None,None, factor_bulk],
           ["128 nbands",   "6.0_dielectric_function/a-Beryllium_128",      "blue",   None,None,None, factor_bulk],
           ["96 nbands",    "6.0_dielectric_function/a-Beryllium_96",       "lime",   None,None,None, factor_bulk],
           ["64 nbands",    "6.0_dielectric_function/a-Beryllium_64_k27",   "orange", None,None,None, factor_bulk],
           ["32 nbands",    "6.0_dielectric_function/a-Beryllium_32",       "silver", None,None,None, factor_bulk]]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for α-Beryllium", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6.10_dielec_a-Beryllium_nbands.pdf")

# %%
# α-Beryllium k-points

systems = [
           ["(45, 45, 45)", "6.0_dielectric_function/a-Beryllium_64_k45",   "purple",   None,None,None, factor_bulk],
           ["(39, 39, 39)", "6.0_dielectric_function/a-Beryllium_64_k39",   "violet",   None,None,None, factor_bulk],
           ["(33, 33, 33)", "6.0_dielectric_function/a-Beryllium_64_k33",   "blue",     None,None,None, factor_bulk],
           ["(27, 27, 27)", "6.0_dielectric_function/a-Beryllium_64_k27",   "lime",     None,None,None, factor_bulk],
           ["(21, 21, 21)", "6.0_dielectric_function/a-Beryllium_64_k21",   "yellow",   None,None,None, factor_bulk],
           ["(15, 15, 15)", "6.0_dielectric_function/a-Beryllium_64_k15",   "orange",   None,None,None, factor_bulk]]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for α-Beryllium", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6.10_dielec_a-Beryllium_kpoints.pdf")

# %%
# α-Beryllene

systems = [["256 nbands",   "6.0_dielectric_function/a-Beryllene_256",  "wine",   None,None,None, factor_a],
           ["192 nbands",   "6.0_dielectric_function/a-Beryllene_192",  "purple", None,None,None, factor_a],
           ["160 nbands",   "6.0_dielectric_function/a-Beryllene_160",  "violet", None,None,None, factor_a],
           ["128 nbands",   "6.0_dielectric_function/a-Beryllene_128",  "blue",   None,None,None, factor_a],
           ["96 nbands",    "6.0_dielectric_function/a-Beryllene_96",   "lime",   None,None,None, factor_a],
           ["64 nbands",    "6.0_dielectric_function/a-Beryllene_64",   "yellow", None,None,None, factor_a],]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for α-Beryllene", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6.11_dielec_a-Beryllene.pdf")

# %%
# β-Beryllene

systems = [["256 nbands",   "6.0_dielectric_function/b-Beryllene_256",  "wine",   None,None,None, factor_b],
           ["192 nbands",   "6.0_dielectric_function/b-Beryllene_192",  "purple", None,None,None, factor_b],
           ["160 nbands",   "6.0_dielectric_function/b-Beryllene_160",  "violet", None,None,None, factor_b],
           ["128 nbands",   "6.0_dielectric_function/b-Beryllene_128",  "blue",   None,None,None, factor_b],
           ["96 nbands",    "6.0_dielectric_function/b-Beryllene_96",   "lime",   None,None,None, factor_b],
           ["64 nbands",    "6.0_dielectric_function/b-Beryllene_64",   "yellow", None,None,None, factor_b]]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for β-Beryllene", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6.12_dielec_b-Beryllene.pdf")

# %%
# cubic Beryllium nbands

systems = [["160 nbands",   "6.0_dielectric_function/c0-Beryllium_160",     "violet", None,None,None, factor_bulk],
           ["128 nbands",   "6.0_dielectric_function/c0-Beryllium_128",     "blue",   None,None,None, factor_bulk],
           ["96 nbands",    "6.0_dielectric_function/c0-Beryllium_96",      "lime",   None,None,None, factor_bulk],
           ["64 nbands",    "6.0_dielectric_function/c0-Beryllium_64_k27",  "orange", None,None,None, factor_bulk],
           ["32 nbands",    "6.0_dielectric_function/c0-Beryllium_32",      "silver", None,None,None, factor_bulk],]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for cubic Beryllium", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6.20_dielec_c-Beryllium_nbands.pdf")

# %%
# cubic Beryllium k-points

systems = [
           ["(45, 45, 45)", "6.0_dielectric_function/c0-Beryllium_64_k45",  "purple",   None,None,None, factor_bulk],
           ["(39, 39, 39)", "6.0_dielectric_function/c0-Beryllium_64_k39",  "violet",   None,None,None, factor_bulk],
           ["(33, 33, 33)", "6.0_dielectric_function/c0-Beryllium_64_k33",  "blue",     None,None,None, factor_bulk],
           ["(27, 27, 27)", "6.0_dielectric_function/c0-Beryllium_64_k27",  "lime",     None,None,None, factor_bulk],
           ["(21, 21, 21)", "6.0_dielectric_function/c0-Beryllium_64_k21",  "yellow",   None,None,None, factor_bulk],
           ["(15, 15, 15)", "6.0_dielectric_function/c0-Beryllium_64_k15",  "orange",   None,None,None, factor_bulk]]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for cubic Beryllium", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6.20_dielec_c-Beryllium_kpoints.pdf")

# %%
# cubic Beryllene trilayer

systems = [["256 nbands",   "6.0_dielectric_function/c3-Beryllene_256",     "wine",   None,None,None, factor_c],
           ["192 nbands",   "6.0_dielectric_function/c3-Beryllene_192",     "purple", None,None,None, factor_c],
           ["160 nbands",   "6.0_dielectric_function/c3-Beryllene_160",     "violet", None,None,None, factor_c],
           ["128 nbands",   "6.0_dielectric_function/c3-Beryllene_128",     "blue",   None,None,None, factor_c],
           ["96 nbands",    "6.0_dielectric_function/c3-Beryllene_96",      "lime",   None,None,None, factor_c],
           ["64 nbands",    "6.0_dielectric_function/c3-Beryllene_64",      "yellow", None,None,None, factor_c]]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for cubic Beryllene trilayer", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6.21_dielec_c-Beryllene_trilayer.pdf")

# %% [markdown]
# # Dielectric function

# %%
# Prework

from vmatplot.dielectric_function import *
import matplotlib.pyplot as plt

# system factors (d_c, (z_max-z_min)*d_c+2*r_be) r_be = 1.98
factor_bulk = (1, 1)                                        # for α-Beryllium and bulk bcc beryllium
factor_a = (40, 2*1.98)                                     # for α-beryllene monolayer
factor_b = (40, 0.0473771641975619+2*1.98)                  # for β-beryllene monolayer
factor_c = (40, 0.0751622445053417+2*1.98)                  # for cubic beryllene trilayer

data_boundary = (-60, 80)

# %%
# dielectric function

systems = [
           ["bulk hcp beryllium",       "6.0_dielectric_selection/a-Beryllium",  "violet",   None,None,None, factor_bulk],
           ["α-beryllene",              "6.0_dielectric_selection/a-beryllene",  "blue",     None,None,None, factor_a],
           ["β-beryllene",              "6.0_dielectric_selection/b-beryllene",  "lime",     None,None,None, factor_b],
           ["bulk bcc beryllium",       "6.0_dielectric_selection/c0-Beryllium", "purple",   None,None,None, factor_bulk],
           ["cubic beryllene trilayer", "6.0_dielectric_selection/c3-beryllene", "orange",   None,None,None, factor_c]
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6_dielectric/6.10_dielec.pdf")
plt.savefig("figures_for_publication/fig3.16_dielec.pdf")

# %%
# hexagonal family

systems = [
           ["bulk hcp beryllium",       "6.0_dielectric_selection/a-Beryllium",  "violet",   None,None,None, factor_bulk],
           ["α-beryllene",              "6.0_dielectric_selection/a-beryllene",  "blue",     None,None,None, factor_a],
           ["β-beryllene",              "6.0_dielectric_selection/b-beryllene",  "lime",     None,None,None, factor_b]
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for hexagonal family", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6_dielectric/6.11_dielec_hex.pdf")

# %%
# cubic family

systems = [
           ["bulk bcc beryllium",     "6.0_dielectric_selection/c0-Beryllium", "purple",   None,None,None, factor_bulk],
           ["cubic beryllene trilayer", "6.0_dielectric_selection/c3-beryllene", "orange",   None,None,None, factor_c]
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for cubic family", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6_dielectric/6.12_dielec_cubic.pdf")

# %%
# Hydrogen adhesion

# system factors (d_c, (z_max-z_min)*d_c+r_upper+r_lower) r_be = 1.98 r_h = 0.70
factor_a = (40, 2*1.98)
factor_b = (40, 0.0473771641975619+2*1.98)
factor_ahh = (40, 0.04361280878130169+2*0.70)
factor_bh = (40, 0.07108860259770651+0.70+1.98)
factor_bhh = (40, 0.0948207854203246+2*0.70)

systems = [
           ["α-beryllene",                "6.0_dielectric_selection/a-beryllene",     "blue",     None,None,None, factor_a],
           ["2H-terminated α-beryllene",  "6.0_dielectric_selection/a-beryllene_hh",  "violet",   None,None,None, factor_ahh],
           ["β-beryllene",                "6.0_dielectric_selection/b-beryllene",     "lime",     None,None,None, factor_b],
           ["H-terminated β-beryllene",   "6.0_dielectric_selection/b-beryllene_b",   "yellow",   None,None,None, factor_bh],
           ["2H-terminated β-beryllene",  "6.0_dielectric_selection/b-beryllene_bb",  "orange",   None,None,None, factor_bhh],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6_dielectric/6.20_dielec_with_Hydrogen.pdf")
plt.savefig("figures_for_publication/fig3.18_dielec_H.pdf")

# %%
# Hydrogen adhesion α-family

systems = [
           ["α-beryllene",                "6.0_dielectric_selection/a-beryllene",     "blue",     None,None,None, factor_a],
           ["H-terminated α-beryllene",                "6.0_dielectric_selection/a-beryllene_hh",  "violet",   None,None,None, factor_ahh],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for α-family Hydrogen adhesion", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6_dielectric/6.21_dielec_a.pdf")

# %%
# Hydrogen adhesion β-family

systems = [
           ["β-beryllene",                "6.0_dielectric_selection/b-beryllene",     "lime",     None,None,None, factor_b],
           ["H-terminated β-beryllene",                "6.0_dielectric_selection/b-beryllene_b",   "yellow",   None,None,None, factor_bh],
           ["2H-terminated β-beryllene",                "6.0_dielectric_selection/b-beryllene_bb",  "orange",   None,None,None, factor_bhh],
           ]

components = [{"xx":"xx-component"},{"yy":"yy-component"},{"zz":"zz-component"}]

plot_dielectric_function("Dielectric function for β-family Hydrogen adhesion", systems, components, "hor", True, "eV", (0,12), data_boundary, True)
plt.savefig("figures/6_dielectric/6.22_dielec_b.pdf")

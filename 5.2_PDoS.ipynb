# %% [markdown]
# # Projected Density of State

# %%
# prework

from vmatplot.pdos import plot_single_pdos
import matplotlib.pyplot as plt

# %%
# α-Beryllium bulk

be_index = [1]
current_dict = "5.0_PDoS/a-Beryllium"

systems = [
           ["Total DOS", current_dict, [], "total_dos", "silver", "solid", 2.0, 1.0],
           ["Total PDoS", current_dict, [], "total", "grey", "solid", 2.0, 1.0],
           ["$p$", current_dict, be_index, "p", "blue", "solid", 2.0, 1.0],
           ["$s$", current_dict, be_index, "s", "blue", "dashed", 2.0, 1.0]
           ]

plot_single_pdos("PDoS for α-Beryllium bulk", systems, 4, 2)
# plt.savefig("figures/5_pdos/5.10_a-Beryllium.pdf")

# %%
# α-Beryllene

be_index = [1]
current_dict = "5.0_PDoS/a-Beryllene"

systems = [
           ["Total DOS", current_dict, [], "total_dos", "silver", "solid", 2.0, 1.0],
           ["Total PDoS", current_dict, [], "total", "grey", "solid", 2.0, 1.0],
           ["$p$", current_dict, be_index, "p", "blue", "solid", 2.0, 1.0],
           ["$s$", current_dict, be_index, "s", "blue", "dashed", 2.0, 1.0],
           ]

plot_single_pdos("PDoS for α-Beryllene", systems, 4, 1.5)
# plt.savefig("figures/5_pdos/5.11_a-Beryllene.pdf")

# %%
# β-Beryllene

be_index = [1]
current_dict = "5.0_PDoS/b-Beryllene"

systems = [
           ["Total DOS", current_dict, [], "total_dos", "silver", "solid", 2.0, 1.0],
           ["Total PDoS", current_dict, [], "total", "grey", "solid", 2.0, 1.0],
           ["$p$", current_dict, be_index, "p", "blue", "solid", 2.0, 1.0],
           ["$s$", current_dict, be_index, "s", "blue", "dashed", 2.0, 1.0]
           ]

plot_single_pdos("PDoS for β-Beryllene", systems, 4, 2)
# plt.savefig("figures/5_pdos/5.12_b-Beryllene.pdf")

# %%
# cubic Beryllium bulk

be_index = [1]
current_dict = "5.0_PDoS/c0-Beryllium"

systems = [["Total DOS", current_dict, [], "total_dos", "silver", "solid", 2.0, 1.0],
           ["Total PDoS", current_dict, [], "total", "grey", "solid", 2.0, 1.0],
           ["$p$", current_dict, be_index, "p", "blue", "solid", 2.0, 1.0],
           ["$s$", current_dict, be_index, "s", "blue", "dashed", 2.0, 1.0]
           ]

plot_single_pdos("PDoS for cubic Beryllium", systems, 4, 1)
# plt.savefig("figures/5_pdos/5.20_c0-Beryllium.pdf")

# %%
# cubic Beryllene trilayer

be_central = [2]
be_outer = [1,3]

current_dict = "5.0_PDoS/c3-Beryllene"

systems = [["Total DOS", current_dict, [], "total_dos", "silver", "solid", 2.0, 1.0],
           ["Total PDoS", current_dict, [], "total", "grey", "solid", 2.0, 1.0],
           ["$p$ for outer atom",   current_dict, be_outer,     "p", "blue", "solid", 2.0, 1.0],
           ["$s$ for outer atom",   current_dict, be_outer,     "s", "blue", "dashed", 2.0, 1.0],
           ["$p$ for central atom", current_dict, be_central,   "p", "orange", "solid", 2.0, 1.0],
           ["$s$ for central atom", current_dict, be_central,   "s", "orange", "dashed", 2.0, 1.0],
           ]

plot_single_pdos("PDoS for cubic Beryllene trilayer", systems, 4, 3)
# plt.savefig("figures/5_pdos/5.20_c3-Beryllene.pdf")

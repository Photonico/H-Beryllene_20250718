# %% [markdown]
# # Phonon dispersion for hexagonal family

# %%
# prework

from vmatplot.phonon import plot_phonons
import matplotlib.pyplot as plt

y_range = [-20, 30]

# %%
# α-Beryllene monolayer

matters = [["α-Beryllene monolayer", "3.0_phonon_dispersion/a1-Beryllene_monolayer_alt", "violet", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for α-Beryllene monolayer", matters, y_range, None)
plt.savefig("figures/3.12_phonon_a-Beryllene.pdf")

# %%
# g-Beryllene monolayer

matters = [["g-Beryllene monolayer", "3.0_phonon_dispersion/g1-Beryllene_monolayer_5", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for g-Beryllene monolayer", matters, y_range, None)
plt.savefig("figures/3.13_phonon_g-Beryllene.pdf")

# %%
# g-Beryllene bilayer AA

matters = [["g-Beryllene monolayer", "3.0_phonon_dispersion/g2-Beryllene_AA_5", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for g-Beryllene bilayer AA stack", matters, y_range, None)
plt.savefig("figures/3.14_phonon_g_AA.pdf")

# %%
# g-Beryllene bilayer AB

matters = [["g-Beryllene monolayer", "3.0_phonon_dispersion/g2-Beryllene_AB_7", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for g-Beryllene bilayer AB stack", matters, y_range, None)
plt.savefig("figures/3.15_phonon_g_AB.pdf")

# %%
# g-Beryllene bilayer AAA

matters = [["g-Beryllene monolayer", "3.0_phonon_dispersion/g3a-Beryllene_AAA_5", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for g-Beryllene trilayer AAA stack", matters, y_range, None)
plt.savefig("figures/3.16_phonon_g_AAA.pdf")

# %%
# # g-Beryllene bilayer AAB

# matters = [["g-Beryllene monolayer", "3.0_phonon_dispersion/g3b-Beryllene_AAB_5", "blue", "solid", 1.5, 1.0, 0]]

# plot_phonons("Phonon dispersion for g-Beryllene trilayer AAB stack", matters, y_range, None)
# plt.savefig("figures/3.17_phonon_g_AAB.pdf")

# %%
# g-Beryllene bilayer ABA

matters = [["g-Beryllene monolayer", "3.0_phonon_dispersion/g3c-Beryllene_ABA_5", "blue", "solid", 1.5, 1.0, 0]]

plot_phonons("Phonon dispersion for g-Beryllene trilayer ABA stack", matters, y_range, None)
plt.savefig("figures/3.18_phonon_g_ABA.pdf")
